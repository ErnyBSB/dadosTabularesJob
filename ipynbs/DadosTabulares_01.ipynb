# %% [markdown]
# # Prévias no repositório

# %%
#@title Conectando ao repo
#/ conectar ao repositório GitHub https://github.com/ErnyBSB/dadosTabularesJob

# !git clone https://github.com/ErnyBSB/dadosTabularesJob.git
# Out:
# Cloning into 'dadosTabularesJob'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 32 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (32/32), 102.08 KiB | 1.93 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
#@title listando fontes (pode-se listar na pasta ao lado esquerdo)
#/ listar os arquivos em >> sources

# %cd dadosTabularesJob/sources
# !ls
# Out:
# /content/dadosTabularesJob/sources/dadosTabularesJob/sources/dadosTabularesJob/sources/dadosTabularesJob/sources/dadosTabularesJob/sources/dadosTabularesJob/sources
# analfabetismo.xlsx    consumo_elec_br.xlsx    oil-production-tonnes.xls  USD_BRL_Dados.csv
# chuva_fortaleza.xlsx  dengue_pernambuco.xlsx  README.MD

# %%
import pandas as pd

# %%
#@title Importando Analfabetismo 14 entries
# prompt: criar um DataFrame Pandas de nome analfa importando o arquivo /sources/analfabetismo.xlsx


analfa = pd.read_excel('/content/dadosTabularesJob/sources/analfabetismo.xlsx')
analfa
# Out:
#      Ano   Taxa
# 0   1992  16.44
# 1   1995  14.68
# 2   1998  12.86
# 3   1999  12.30
# 4   2001  11.40
# 5   2002  10.90
# 6   2003  10.60
# 7   2004  10.40
# 8   2005  10.05
# 9   2006   9.41
# 10  2007   9.09
# 11  2008   9.20
# 12  2009   8.90
# 13  2011   7.90

# %%
#@title Importando Chuva Fortaleza 130 entries
# prompt: criar um DataFrame Pandas de nome chuva importando o arquivo /sources/chuva_fortaleza.xlsx



# Assuming the file 'chuvafortaleza.xlsx' is in the '/content/dadosTabularesJob/sources/' directory
chuva = pd.read_excel('/content/dadosTabularesJob/sources/chuva_fortaleza.xlsx')
chuva
# Out:
#                     Year  Milimitros
# 0                   1850         852
# 1                   1851        1806
# 2                   1852        1356
# 3                   1853        1233
# 4                   1854        1590
# ..                   ...         ...
# 125  1975-01-01 00:00:00        1778
# 126  1976-01-01 00:00:00        1417
# 127  1977-01-01 00:00:00        1941
# 128  1978-01-01 00:00:00        1752
# 129  1979-01-01 00:00:00         996
#
# [130 rows x 2 columns]

# %%
#@title Importando Consumo ELE 49 entries
# prompt: criar um DataFrame Pandas de nome consumo importando o arquivo /sources/consumo_elec_br.xlsx


consumo = pd.read_excel('/content/dadosTabularesJob/sources/consumo_elec_br.xlsx')
consumo
# Out:
#      Ano           kwh
# 0   1970   3410.083421
# 1   1971   3855.213298
# 2   1972   4284.439538
# 3   1973   4875.710935
# 4   1974   5445.404966
# 5   1975   6004.869091
# 6   1976   6815.180837
# 7   1977   7637.097938
# 8   1978   8513.947058
# 9   1979   9542.783359
# 10  1980  10548.408948
# 11  1981  10851.609619
# 12  1982  11482.855020
# 13  1983  12371.567393
# 14  1984  13754.496000
# 15  1985  14920.533398
# 16  1986  16081.498826
# 17  1987  16570.313065
# 18  1988  17528.669868
# 19  1989  18257.460094
# 20  1990  18711.014599
# 21  1991  19374.239203
# 22  1992  19812.663763
# 23  1993  20732.065855
# 24  1994  21473.605121
# 25  1995  22764.120708
# 26  1996  23871.357636
# 27  1997  25333.116698
# 28  1998  26394.018168
# 29  1999  27143.896097
# 30  2000  28522.918427
# 31  2001  26626.039322
# 32  2002  27895.404620
# 33  2003  29430.318000
# 34  2004  30955.270000
# 35  2005  32266.597542
# 36  2006  33535.734400
# 37  2007  35443.233303
# 38  2008  36829.460917
# ...

# %%
#@title Importando Dengue 887 entries
# prompt: criar um DataFrame Pandas de nome dengue importando o arquivo /sources/dengue_pernambuco.xlsx

dengue = pd.read_excel('/content/dadosTabularesJob/sources/dengue_pernambuco.xlsx')
dengue
# Out:
#          semana  valor
# 0    2000-01-08    686
# 1    2000-01-15    611
# 2    2000-01-22    614
# 3    2000-01-29    598
# 4    2000-02-05    785
# ..          ...    ...
# 882  2016-12-03     73
# 883  2016-12-10     97
# 884  2016-12-17     80
# 885  2016-12-24     50
# 886  2016-12-31     29
#
# [887 rows x 2 columns]

# %%
#@title Importando Dados Dolar 2512 entries
# prompt: criar um DataFrame Pandas de nome dolar importando o arquivo .CSV  /sources/USD_BRL_Dados.csv


dolar = pd.read_csv('/content/dadosTabularesJob/sources/USD_BRL_Dados.csv')
dolar
# Out:
#             Data  Último Abertura  Máxima  Mínima    Var%
# 0     19.08.2019  3,9953   4,0030  4,0030  3,9930  -0,26%
# 1     16.08.2019  4,0058   3,9918  4,0080  3,9749   0,37%
# 2     15.08.2019  3,9910   4,0503  4,0515  3,9785  -1,52%
# 3     14.08.2019  4,0526   3,9639  4,0539  3,9624   2,18%
# 4     13.08.2019  3,9660   3,9862  4,0136  3,9454  -0,49%
# ...          ...     ...      ...     ...     ...     ...
# 2507  07.01.2010  1,7465   1,7310  1,7518  1,7310   0,81%
# 2508  06.01.2010  1,7325   1,7296  1,7393  1,7241   0,09%
# 2509  05.01.2010  1,7310   1,7193  1,7398  1,7145   0,57%
# 2510  04.01.2010  1,7212   1,7288  1,7338  1,7161  -1,25%
# 2511  01.01.2010  1,7430   1,7430  1,7430  1,7430   0,00%
#
# [2512 rows x 6 columns]
